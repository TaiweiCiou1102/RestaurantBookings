# %%
import os
cwd = os.getcwd()
if os.path.basename(cwd) == 'notebooks':
    os.chdir('..')
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: d:\Taiwei\RestaurantBookings

# %%
import pandas as pd
import duckdb

# %%
from enum import member
order_columns = ['booking_id', 'member_id', 'cdate', 'restaurant_id', 'datetime', 'people', 'gender', 'status', 'is_required_prepay_satisfied', 'return90']
restaurant_columns = ['id', 'is_hotel', 'country', 'currency', 'cityarea','name','abbr','tel','opening_hours','good_for_family','accept_credit_card','parking','outdoor_seating','wifi','wheelchair_accessible','price1','price2','lat','lng','timezone','locale','cdate']
member_columns = ['id', 'is_vip','gender','birthdate','city','has_google_id', 'has_yahoo_id','has_weibo_id', 'cdate']

# %%
order = pd.read_csv('./data/raw/train.csv', header = 1, names = order_columns)
#restaurant = pd.read_csv('./data/raw/restaurant_revised.csv', header = 1, names = restaurant_columns)
#member = pd.read_csv('./data/raw/member.csv', header = 1, names = member_columns)

# %%
joined_sql = """
    SELECT
        
"""
